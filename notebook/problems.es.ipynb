# %% [markdown]
# # Problemas de distribución de probabilidad

# %%
from scipy.stats import binom, norm, uniform
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def pmf_binomial(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result


def cdf_binomial(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n= size, p= prob, loc = 0)

    return result


def ppf_binomial(p, size, prob=0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q=p, n=size, p=prob, loc=0)

    return result


def rvs_binomial(n, size, prob =0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n=size, p=prob, size=n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {pmf_binomial(2, size=10, prob=0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {cdf_binomial(2, size=10, prob=0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {ppf_binomial(0.9, size=10, prob=0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rvs_binomial(2000, size=10, prob=0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
np.random.seed(42)

size = 10
prob = 0.2
data = rvs_binomial(2000, size=10, prob=0.2)

pmf = pmf_binomial(data, size=size, prob=prob)
cdf = cdf_binomial(data, size=size, prob=prob)
ppf = ppf_binomial(data, size=size, prob=prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %% [markdown]
# Distribuciones Normales

# %%
def pdf_norm(data, mean, std):
    """
    Calcula la estimación puntual de la distribución normal.
    """
    result = norm.pdf(data,scale=std, loc=mean)

    return result

def cdf_norm(data, mean, std):
    """
    Calcula el acumulado de la distribución normal.
    """
    result = norm.cdf(data,scale=std, loc=mean)

    return result


def ppf_norm(data, mean, std):
    """
    Calcula la función cuantil a partir de la distribución normal.
    """
    result = norm.ppf(data,scale=std, loc=mean)

    return result


def rvs_norm(data, mean, std):
    """
    Genera variables aleatorias a partir de la distribución normal.
    """
    result = norm.rvs(data,scale=std, loc=mean)

    return result

# %%
np.random.seed(42)

mean = 1
std = 0.2
data = data = np.arange(-5, 5, 0.01)

pdf = pdf_norm(data, mean, std)
cdf = cdf_norm(data, mean, std)
ppf = ppf_norm(data, mean, std)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].plot(data, pdf, "r-")
axis[0].set_title("Función de Densidad (PDF)")
axis[1].plot(data, cdf, "b-")
axis[1].set_title("Función de Distribución Acumulada (CDF)")
axis[2].plot(data, ppf, "g-")
axis[2].set_title("Función Cuantil (PPF)")


# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Distribuciones Uniformes

# %%
def pdf_uniform(x, loc=0, scale=1):
    """
    Calcula la densidad de probabilidad (PDF) de la distribución uniforme continua.
    """
    result = uniform.pdf(x, loc=loc, scale=scale)
    return result

def cdf_uniform(q, loc=0, scale=1):
    """
    Calcula la función de distribución acumulada (CDF) de la distribución uniforme continua.
    """
    result = uniform.cdf(q, loc=loc, scale=scale)
    return result

def ppf_uniform(p, loc=0, scale=1):
    """
    Calcula la función cuantil (inversa de la CDF) de la distribución uniforme continua.
    """
    result = uniform.ppf(p, loc=loc, scale=scale)
    return result

def rvs_uniform(n, loc=0, scale=1):
    """
    Genera variables aleatorias a partir de la distribución uniforme continua.
    """
    result = uniform.rvs(loc=loc, scale=scale, size=n)
    return result

# %%
# Semilla para reproducibilidad
np.random.seed(42)

# Parámetros de la distribución uniforme continua
loc = 1     # Límite inferior
scale = 4   # Ancho del intervalo → intervalo [1, 5)

# Dominio para graficar PDF y CDF
data = np.linspace(-1, 7, 1000)  # Se incluye un poco fuera del rango para ver los bordes
pdf = pdf_uniform(data, loc, scale)
cdf = cdf_uniform(data, loc, scale)

# Dominio para graficar PPF → valores entre 0 y 1
probs = np.linspace(0, 1, 1000)
ppf = ppf_uniform(probs, loc, scale)

# Crear subplots
fig, axis = plt.subplots(3, 1, figsize=(5, 7))

axis[0].plot(data, pdf, "r-", label="PDF")
axis[0].set_title("Función de Densidad (PDF)")
axis[0].grid(True)

axis[1].plot(data, cdf, "b-", label="CDF")
axis[1].set_title("Función de Distribución Acumulada (CDF)")
axis[1].grid(True)

axis[2].plot(probs, ppf, "g-", label="PPF")
axis[2].set_title("Función Cuantil (PPF)")
axis[2].grid(True)


# Ajustar diseño
plt.tight_layout()
plt.show()
